# %%
import torch
import matplotlib.pyplot as plt
import random

# Load the occluded MNIST dataset
occluded_mnist = torch.load('/home/mila/m/mingze.li/occluded dataset/occluded_mnist_train.pt')

# %%
# Select a random image and display it
img, target = random.choice(occluded_mnist)
plt.imshow(img.squeeze(), cmap='gray')
plt.title(f'Occluded MNIST image with target label: {target}')
plt.show()
